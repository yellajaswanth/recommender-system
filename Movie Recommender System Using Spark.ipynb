# %% [markdown]
# ## MovieLens Dataset

# %% [markdown]
# We will be using movielens dataset for movie recommender system. There are basically two types of dataset SMALL & FULL.
#
# As per the website (https://grouplens.org/datasets/movielens/), <br>
# <strong>Small:</strong> 100,000 ratings and 1,300 tag applications applied to 9,000 movies by 700 users. Last updated 10/2016.<br>
# <strong>Full:</strong> 26,000,000 ratings and 750,000 tag applications applied to 45,000 movies by 270,000 users. Includes tag genome data with 12 million relevance scores across 1,100 tags. Last updated 8/2017.

# %%
small_dataset_url = 'http://files.grouplens.org/datasets/movielens/ml-latest-small.zip'
full_dataset_url = 'http://files.grouplens.org/datasets/movielens/ml-latest.zip'

# %% [markdown]
# ### Download Files

# %%
# !wget {small_dataset_url} -P data/
# !wget {full_dataset_url} -P data/

# %% [markdown]
# ### Extract Files

# %%
# !unzip data/ml-latest-small.zip -d data/
# !unzip data/ml-latest.zip -d data/

# %%
import pandas as pd
import numpy as np

# %%
ratings_df = pd.read_csv('data/ml-latest-small/ratings.csv')
ratings_df = ratings_df[['userId','movieId','rating']]
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
movies_df = pd.read_csv('data/ml-latest-small/movies.csv')
movies_df = movies_df[['movieId','title']]
movies_df.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
num_users = len(ratings_df['userId'].unique())
num_movies = len(ratings_df['movieId'].unique())
print('Number of Users : {}'.format(num_users))
print('Number of Movies: {}'.format(num_movies))
# Out:
# Number of Users : 671
# Number of Movies: 9066

# %%
from sklearn import cross_validation as cv
train, test = cv.train_test_split(ratings_df, test_size=0.25)
# Out:
# /users/yeljh2/miniconda2/envs/tensorflow/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train.head()
# Out:
#        userId  movieId  rating
# 78739     547     1236     3.0
# 34602     247     1320     3.0
# 81945     559     1193     5.0
# 50318     370     1645     4.5
# 66043     468     1962     3.0

# %%
def create_matrix(df):
    users = df['userId'].unique()
    movies = df['movieId'].unique()
    mat = pd.DataFrame(index=users,columns=movies).fillna(value=0)
    for idx,row in df.iterrows():
        user = row['userId']
        movie = row['movieId']
        value = row['rating']
        mat.at[user,movie] = value
    return mat

# %%
train_matrix = create_matrix(train)
test_matrix = create_matrix(test)

# %%
from sklearn.metrics.pairwise import pairwise_distances
user_similarity = pairwise_distances(train_matrix, metric='cosine')
item_similarity = pairwise_distances(train_matrix.T, metric='cosine')

# %%
def predict(ratings, similarity, type='user'):
    if type == 'user':
        mean_user_rating = ratings.mean(axis=1)
        ratings_diff = (ratings - mean_user_rating[:, np.newaxis])
        pred = mean_user_rating[:, np.newaxis] + similarity.dot(ratings_diff) / np.array([np.abs(similarity).sum(axis=1)]).T
    elif type == 'item':
        pred = ratings.dot(similarity) / np.array([np.abs(similarity).sum(axis=1)])
    return pred

# %%
item_prediction = predict(train_matrix.as_matrix(), item_similarity, type='item')
user_prediction = predict(train_matrix.as_matrix(), user_similarity, type='user')

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten()
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
print ('User-based CF RMSE: ' + str(rmse(user_prediction, test_matrix.as_matrix())))
print ('Item-based CF RMSE: ' + str(rmse(item_prediction, test_matrix.as_matrix())))
# Out:
# User-based CF RMSE: 3.557193493162695
# Item-based CF RMSE: 3.628474744819959

# %%
item_prediction = pd.DataFrame(item_similarity, index = train_matrix.columns, columns = train_matrix.columns )
item_prediction = item_prediction.stack().reset_index()
item_prediction.rename({'level_0':'movie1','level_1':'movie2',0:'score'},axis='columns',inplace=True)

# %%
item_prediction.head()
# Out:
#    movie1  movie2     score
# 0    1236    1236  0.000000
# 1    1236    1320  0.859766
# 2    1236    1193  0.896463
# 3    1236    1645  0.891674
# 4    1236    1962  0.933397

# %%
movies_df = movies_df[['movieId','title']]
movies_df = movies_df.drop_duplicates()
movieMap = movies_df.set_index("movieId").title
movieMap = movieMap.loc[~movieMap.index.duplicated(keep='first')]

# %%
item_prediction['title1'] = item_prediction.movie1.map(movieMap)
item_prediction['title2'] = item_prediction.movie2.map(movieMap)
item_prediction = item_prediction[['title1','title2','score']]
item_prediction = pd.concat([pd.DataFrame(np.sort(item_prediction[['title1','title2']],1), index=item_prediction.index), item_prediction['score']], axis=1)

# %%
item_prediction.rename({0:'title1',1:'title2'},axis='columns',inplace=True)

# %%
item_prediction['title1_year'] = item_prediction['title1'].str[-5:]
item_prediction['title1_year'] = item_prediction['title1_year'].str.replace(')','')
item_prediction['title1_year'] = item_prediction['title1_year'].astype(int, errors'ignore')

# %%
item_prediction = item_prediction.drop_duplicates()
item_prediction[item_prediction.title1=='Avengers, The (2012)'].sort_values('score',ascending=True)
# Out:
#                        title1  \
# 6494126  Avengers, The (2012)
# 2266100  Avengers, The (2012)
# 6497299  Avengers, The (2012)
# 6494258  Avengers, The (2012)
# 6495154  Avengers, The (2012)
# 6496308  Avengers, The (2012)
# 3803564  Avengers, The (2012)
# 2764958  Avengers, The (2012)
# 6494221  Avengers, The (2012)
# 6498559  Avengers, The (2012)
# 2257922  Avengers, The (2012)
# 3239282  Avengers, The (2012)
# 6494283  Avengers, The (2012)
# 6494143  Avengers, The (2012)
# 6494615  Avengers, The (2012)
# 6494962  Avengers, The (2012)
# 1734530  Avengers, The (2012)
# 5635436  Avengers, The (2012)
# 6495391  Avengers, The (2012)
# 6496303  Avengers, The (2012)
# 6496828  Avengers, The (2012)
# 6496457  Avengers, The (2012)
# 6497373  Avengers, The (2012)
# 6497898  Avengers, The (2012)
# 6498210  Avengers, The (2012)
# 6499053  Avengers, The (2012)
# 4523228  Avengers, The (2012)
# 6496470  Avengers, The (2012)
# 6494580  Avengers, The (2012)
# 6494953  Avengers, The (2012)
# ...                       ...
# 6498767  Avengers, The (2012)
# 6498766  Avengers, The (2012)
# 6495996  Avengers, The (2012)
# 6495995  Avengers, The (2012)
# 6495991  Avengers, The (2012)
# 6498739  Avengers, The (2012)
# 6498740  Avengers, The (2012)
# 6498741  Avengers, The (2012)
# 6498742  Avengers, The (2012)
# 6498744  Avengers, The (2012)
# 6495989  Avengers, The (2012)
# 6498746  Avengers, The (2012)
# 6495988  Avengers, The (2012)
# 6498749  Avengers, The (2012)
# 6498808  Avengers, The (2012)
# 6498750  Avengers, The (2012)
# 6498753  Avengers, The (2012)
# 6495982  Avengers, The (2012)
# 6498756  Avengers, The (2012)
# 6498757  Avengers, The (2012)
# 6498758  Avengers, The (2012)
# 6498759  Avengers, The (2012)
# 6495978  Avengers, The (2012)
# 6498761  Avengers, The (2012)
# 6495975  Avengers, The (2012)
# 6498763  Avengers, The (2012)
# 6495974  Avengers, The (2012)
# 6498765  Avengers, The (2012)
# 6498752  Avengers, The (2012)
# 6501509  Avengers, The (2012)
#
#                                                     title2     score  \
# 6494126                               Avengers, The (2012)  0.000000
# 2266100                     Guardians of the Galaxy (2014)  0.274420
# 6497299                                        Thor (2011)  0.414472
# 6494258                                    Iron Man (2008)  0.436875
# 6495154                          X-Men: First Class (2011)  0.441359
# 6496308        Hobbit: The Desolation of Smaug, The (2013)  0.468035
# 3803564                      Dark Knight Rises, The (2012)  0.476154
# 2764958                                     Elysium (2013)  0.481796
# 6494221                                  Zombieland (2009)  0.484881
# 6498559                        Thor: The Dark World (2013)  0.488188
# 2257922                                  Iron Man 2 (2010)  0.489093
# 3239282                  X-Men: Days of Future Past (2014)  0.508578
# 6494283                              Wreck-It Ralph (2012)  0.511412
# 6494143                                     Super 8 (2011)  0.511473
# 6494615                                Tron: Legacy (2010)  0.516165
# 6494962                                Man of Steel (2013)  0.516481
# 1734530                                   Star Trek (2009)  0.516604
# 5635436                             Sherlock Holmes (2009)  0.523623
# 6495391          Sherlock Holmes: A Game of Shadows (2011)  0.528458
# 6496303                                    Megamind (2010)  0.528654
# 6496828                                 Source Code (2011)  0.533991
# 6496457                                 World War Z (2013)  0.541659
# 6497373                         Battle: Los Angeles (2011)  0.542142
# 6497898                                Ender's Game (2013)  0.542958
# 6498210                                 Daybreakers (2010)  0.542993
# 6499053                                 Warm Bodies (2013)  0.544741
# 4523228                        Terminator Salvation (2009)  0.545631
# 6496470          Captain America: The First Avenger (2011)  0.548226
# 6494580                                   Limitless (2011)  0.549035
# 6494953                                     Skyfall (2012)  0.550794
# ...                                                    ...       ...
# 6498767                   Deep Red (Profondo rosso) (1975)  1.000000
# 6498766                   Babylon 5: A Call to Arms (1999)  1.000000
# 6495996                      War of the Worlds, The (1953)  1.000000
# 6495995                                   No Escape (1994)  1.000000
# 6495991                                   Testament (1983)  1.000000
# 6498739                                  Taxidermia (2006)  1.000000
# 6498740                                Men of Honor (2000)  1.000000
# 6498741                            Imagine Me & You (2005)  1.000000
# 6498742                                New Guy, The (2002)  1.000000
# 6498744                     Yeh Jawaani Hai Deewani (2013)  1.000000
# 6495989                          Surviving the Game (1994)  1.000000
# 6498746                Turbo: A Power Rangers Movie (1997)  1.000000
# 6495988                                  Bloodsport (1988)  1.000000
# 6498749                                        Bent (1997)  1.000000
# 6498808                                        Shag (1989)  1.000000
# 6498750                        Tuesdays with Morrie (1999)  1.000000
# 6498753                             Picture Perfect (1997)  1.000000
# 6495982                   Hedwig and the Angry Inch (2000)  1.000000
# 6498756             Shivers (They Came from Within) (1975)  1.000000
# 6498757                                  Swept Away (2002)  1.000000
# 6498758           Lagaan: Once Upon a Time in India (2001)  1.000000
# 6498759                                     Foxfire (1996)  1.000000
# 6495978                                    Fandango (1985)  1.000000
# 6498761             Curse of the Jade Scorpion, The (2001)  1.000000
# 6495975                           It Might Get Loud (2008)  1.000000
# 6498763                      Day of the Jackal, The (1973)  1.000000
# 6495974                                 Fever Pitch (1997)  1.000000
# 6498765                                   Dragonfly (2002)  1.000000
# 6498752  Girl on the Bridge, The (Fille sur le pont, La...  1.000000
# 6501509                   Knockin' on Heaven's Door (1997)  1.000000
#
#         title1_year
# 6494126        2012
# 2266100        2012
# 6497299        2012
# 6494258        2012
# 6495154        2012
# 6496308        2012
# 3803564        2012
# 2764958        2012
# 6494221        2012
# 6498559        2012
# 2257922        2012
# 3239282        2012
# 6494283        2012
# 6494143        2012
# 6494615        2012
# 6494962        2012
# 1734530        2012
# 5635436        2012
# 6495391        2012
# 6496303        2012
# 6496828        2012
# 6496457        2012
# 6497373        2012
# 6497898        2012
# 6498210        2012
# 6499053        2012
# 4523228        2012
# 6496470        2012
# 6494580        2012
# 6494953        2012
# ...             ...
# 6498767        2012
# 6498766        2012
# 6495996        2012
# 6495995        2012
# 6495991        2012
# 6498739        2012
# 6498740        2012
# 6498741        2012
# 6498742        2012
# 6498744        2012
# 6495989        2012
# 6498746        2012
# 6495988        2012
# 6498749        2012
# 6498808        2012
# 6498750        2012
# 6498753        2012
# 6495982        2012
# 6498756        2012
# 6498757        2012
# 6498758        2012
# 6498759        2012
# 6495978        2012
# 6498761        2012
# 6495975        2012
# 6498763        2012
# 6495974        2012
# 6498765        2012
# 6498752        2012
# 6501509        2012
#
# [7622 rows x 4 columns]
